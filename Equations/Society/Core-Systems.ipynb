# %% [markdown]
# - How constitutions define governmental authority and limits.
# - How legislation becomes law.
# - How executive agencies implement and enforce laws.
# - How courts interpret law and create legal precedent.
# - How budgets constrain government behaviour and priorities.
# - How taxation funds the state and shapes incentives.
# - How central banks influence money, credit, inflation, and financial stability.
# - How public finance, debt, and bond markets affect national decision-making.
# - How capital is allocated (banks, venture capital, private equity, public markets, institutional investors).
# - How corporations are governed and make strategic decisions.
# - How startups form, scale, raise capital, and compete with incumbents.
# - How incentives shape behaviour across governments, markets, and organizations.
# - How organizations process information, make decisions, and coordinate internally.
# - How regulation changes market behaviour and industry structure.
# - How lobbying, interest groups, and political incentives influence policy.
# - How media, education, and digital platforms shape public opinion and legitimacy.
# - How geopolitical strategy, trade, energy, technology, and defence influence national policy.
# - How institutions evolve over decades while preserving stability.
# - How feedback loops connect law → institutions → markets → society → politics → law.
# - Always ask: **Which mechanism produced this outcome, and where is the highest-leverage point to change it?**
