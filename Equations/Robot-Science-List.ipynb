# %% [markdown]
# # Fundamental Science
#
# ## Math
#
# Pre-Calculus:
#
# * Quadratic Equations
# * Discriminant Analysis
# * Parabolic Charged Particle Trajectories in Uniform Electric Fields
# * Electrostatic Potential Well Minimization
# * Polynomial Functions
# * Field Boundary Approximations
# * Trigonometric Functions
# * SOH CAH TOA
# * Pythagorean Identity
# * Harmonic Synthesis
# * Sinusoidal AC Voltage Waveforms
# * Sinusoidal AC Current Waveforms
# * Phase Shifts
# * Instantaneous AC Power Calculations
# * Complex Numbers
# * Polar Form Representations
# * Euler's Formula
# * Complex Exponentials
# * Taylor Series Expansions
# * Complex Impedance
# * Phasor Representation of AC Signals
#
# Calculus:
#
# * Limit Definitions
# * Derivative Derivations
# * Instantaneous Current as Charge Rate of Change
# * Induced Electromotive Force
# * Rate of Magnetic Flux Change
# * Riemann Integration
# * Fundamental Theorem of Calculus
# * Total Accumulated Charge Integrals
# * Energy Storage in Electric Fields
# * Energy Storage in Magnetic Fields
# * Root Mean Square Voltage Evaluation
# * Root Mean Square Current Evaluation
# * First Order Linear Ordinary Differential Equations
# * Second Order Linear Ordinary Differential Equations
# * Transient Response in RC Circuit Networks
# * Transient Response in RL Circuit Networks
# * Transient Response in RLC Circuit Networks
# * Damped Electrical Resonance
# * Quality Factor Dynamics
# * Multivariable Calculus
# * Partial Derivatives
# * Double Integrals
# * Triple Integrals
#
# Vector Calculus:
#
# * Scalar Spatial Fields
# * Vector Spatial Fields
# * Gradient
# * Electrostatic Potential Surfaces
# * Divergence
# * Electric Charge Density
# * Curl
# * Magnetic Circulation
# * Gauss's Divergence Theorem
# * Stokes' Theorem
# * Circulation Integrals
# * Green's Theorem
#
# Linear Algebra:
#
# * Vectors
# * Vector Spaces
# * Admittance Matrix Formulations
# * Impedance Matrix Formulations
# * Matrices
# * Matrix Operations
# * Nodal Circuit Equations
# * LU Decomposition
# * QR Decomposition
# * Singular Value Decomposition
# * Multi-Port Network Reduction
# * Eigenvalues
# * Eigenvectors
# * Basis Transformations
# * Coordinate Systems
# * Orthogonality
# * Inner Products
# * Gram-Schmidt Orthogonalization
#
# Transforms:
#
# * Orthogonality of Trigonometric Basis Functions
# * Fourier Series Derivation
# * Continuous Signal Decomposition
# * Fourier Transforms
# * Continuous Fourier Transform
# * Discrete Fourier Transform
# * Fast Fourier Transform
# * Waveform Frequency Spectra
# * Total Harmonic Distortion
# * High-Frequency Skin Depth Effects in Power Conductors
# * Laplace Transforms
# * Inverse Laplace Transform
# * Convergence Domains
# * s-Domain Circuit Analysis
# * Transfer Functions
# * Network Pole Stability Analysis
# * Network Zero Stability Analysis
#
# ## Electromagnetism
#
# Electrostatics:
#
# * Coulomb's Law
# * Electric Field Density
# * Permittivity of Free Space
# * Permittivity of Bound Media
# * Poisson's Partial Differential Equation
# * Laplace's Partial Differential Equation
# * Boundary Value Problems via Separation of Variables
# * Parallel Plate Capacitance Geometries
# * Coaxial Capacitance Geometries
# * Spherical Capacitance Geometries
# * Electrostatic Energy Density
#
# Magnetostatics:
#
# * Biot-Savart Law
# * Ampere's Circuital Law
# * Magnetic Vector Potential
# * Permeability
# * Magnetic Susceptibility
# * Magnetic Hysteresis Loss Curves
# * Magnetic Reluctance Circuits
# * Core Saturation Dynamics
#
# Electrodynamics and Maxwell's Field Equations:
#
# * Faraday's Law of Induction
# * Maxwell's Equations in Differential Form
# * Maxwell's Equations in Integral Form
# * Displacement Current Density
# * Electromagnetic Wave Equations in Conductors
# * Electromagnetic Wave Equations in Dielectrics
# * Wave Attenuation
# * Phase Constants
# * Poynting Vector
# * Electromagnetic Energy Flux
#
# Electrochemistry and Battery Physics:
#
# * Gibbs Free Energy
# * Cell Potential Derivations
# * Nernst Equation for Non-Standard Cell State
# * Butler-Volmer Reaction Kinetics
# * Fick's Laws of Diffusion
# * Ion Transport
# * Double-Layer Capacitance Dynamics
# * Electrochemical Impedance Spectroscopy
# * Warburg Impedance Modeling
#
# # Electrical Engineering, Electronics and Power Systems
#
# ## Circuit Analysis and Actuation Hardware
#
# Circuit Engineering:
#
# * Electric Current
# * Voltage
# * Resistance
# * Ohm's Law
# * Kirchhoff's Voltage Law
# * Kirchhoff's Current Law
# * Thévenin Circuit Equivalents
# * Norton Circuit Equivalents
# * Nodal Analysis
# * Mesh Current Analysis
# * Maximum Power Transfer Theorem
# * Precision Sensing
# * Current Shunt Measurement Networks
#
# Robotics Actuators and Electromechanics:
#
# * Lorentz Force Generation Physics
# * Brushless DC Motors
# * Permanent Magnet Synchronous Motors
# * Torque Constants
# * Back-EMF Constants
# * Cogging Torque Minimization
# * Reluctance Torque Minimization
# * High-Torque Frameless Direct-Drive Actuators
# * Quasi-Direct Drive Planetary Gearing Integration
#
# Energy Storage Systems:
#
# * Lithium-Ion Cell Thermodynamics (NMC)
# * Lithium-Ion Cell Thermodynamics (LFP)
# * Solid-State Battery Cell Physics
# * State of Charge Estimation via Extended Kalman Filtering
# * State of Health Degradation Modeling
# * Thermal Runaway Dynamics
# * Battery Heat Dissipation
# * Battery Management Systems
# * Passive Cell Balancing Networks
# * Active Cell Balancing Networks
# * Dynamic Burst-Current Sizing for Robotic Actuation
#
# ## Industrial and Grid-Scale Power Systems
#
# Three-Phase Power Distribution:
#
# * Balanced Three-Phase Systems (Wye Configuration)
# * Balanced Three-Phase Systems (Delta Configuration)
# * Unbalanced Three-Phase Systems
# * Active Power Calculations
# * Reactive Power Calculations
# * Apparent Power Calculations
# * Power Factor Analysis
# * Capacitive Power Factor Correction
# * Industrial Step-Up Power Transformers
# * Industrial Step-Down Power Transformers
# * Industrial Grid Power Distribution
# * Plant Power Distribution
# * High-Voltage Charging Depots
# * Industrial Feeder Lines
#
# Industrial Safety and Switchgear:
#
# * Short-Circuit Current Fault Calculations
# * Circuit Breaker Switching
# * Arc Interruption Physics
# * Industrial Switchgear
# * Protective Relay Coordination
# * TN Grounding Architectures
# * TT Grounding Architectures
# * IT Grounding Architectures
# * Arc Flash Energy Estimation
# * Arc Flash Protection
# * Building Sub-Panels
# * Facility Power Wiring
# * Emergency Stop High-Voltage Interlock Routing
#
# ## Semiconductors, Power Converters and Compute Architectures
#
# Power Electronics and Motor Inverters:
#
# * Silicon Carbide Switching Transistors
# * Gallium Nitride Switching Transistors
# * Buck Converter Topology
# * Boost Converter Topology
# * Buck-Boost Converter Topology
# * Isolated Full-Bridge Topology
# * Switching Loss Optimization
# * Conduction Loss Optimization
# * Space Vector Pulse Width Modulation
# * Clarke Transformation
# * Park Transformation
# * Field-Oriented Control Inverters
# * Direct Current Loop Decoupling
# * Quadrature Current Loop Decoupling
# * Field Weakening Speed Expansion Dynamics
#
# Micro-Scale Semiconductors and Compute Hardware:
#
# * P-N Junction Physics
# * Bandgap Engineering
# * MOSFET Channel Formation
# * Sub-Threshold Leakage
# * CMOS Logic Gate Design
# * Parasitic Capacitance
# * Propagation Delay
# * Static Power Dissipation
# * Dynamic Power Dissipation
# * Silicon Compute Architecture
# * Pipeline Mechanics
# * Single Instruction Multiple Data Execution Units
# * Vector Processing
# * GPU Parallel Compute Architectures
# * TPU Systolic Arrays for Massively Parallel Matrix Multiplication
#
# # Mechanics, Controls & FSD
#
# ## Structural Mechanics, CAD and Geometry
#
# Structural Mechanics and Material Science:
#
# * Hooke's Law
# * Stress-Strain Relations
# * Elasticity
# * Tensile Stress
# * Compressive Stress
# * Shear Stress
# * Torsional Stress
# * Mohr's Circle
# * Principal Stresses
# * Von Mises Yield Criteria
# * Structural Material Selection: Aluminum Alloys
# * Structural Material Selection: Titanium
# * Structural Material Selection: Carbon Fiber Composites
# * Stiffness-to-Weight Optimization for Robot Limbs
# * Beam Bending Moments
# * Deflection Minimization
#
# CAD Foundations and 2D Sketching:
#
# * 2D Sketching Fundamentals
# * Geometric Constraints
# * Dimensional Constraints
# * Sketch Entities
# * Sketch Offset Operations
# * Sketch Patterning
# * Fully Defined Sketch Mechanics
#
# Solid Modeling Foundations:
#
# * Extrusion Operations
# * Revolve Operations
# * Sweep Operations
# * Loft Operations
# * Fillet Mechanics
# * Chamfer Mechanics
# * Shell Operations
# * Boolean Operations
# * Feature Tree Management
#
# Advanced Part Design:
#
# * Multi-Body Solid Design
# * Reference Geometry Creation
# * Axis Systems
# * Datum Planes
# * Thin-Wall Plastic Enclosure Design
# * Draft Angles
# * Rib Design
# * Boss Design
# * Threaded Insert Bosses
# * Snap Fit Design
# * Machined Part Design for CNC Milling
# * Lathe Part Design
#
# Advanced Surface Modeling:
#
# * Freeform Surface Design
# * Organic Form Sculpting
# * Surface Extrusion
# * Surface Lofting
# * Boundary Surfaces
# * Surface Trimming
# * Surface Knitting
# * Thickness Creation from Surfaces
# * Aerodynamic Fairings Design
# * Ergonomic Humanoid Shell Modeling
#
# Sheet Metal Design:
#
# * Sheet Metal Flanges
# * Bend Allowance Calculations
# * K-Factor Parameters
# * Sheet Metal Unfolding
# * Flat Pattern Export
# * Sheet Metal Enclosures
# * Stamped Metal Part Design
#
# Mechanical Assemblies:
#
# * Bottom-Up Assembly Modeling
# * Top-Down Parametric Assembly Design
# * Assembly Mates
# * Kinematic Joint Constraints
# * Limit Mates
# * Clearance Analysis
# * Interference Detection
# * Dynamic Motion Analysis
# * Exploded Views
# * Fastener Library Integration
#
# Electrical and Electronics CAD Integration:
#
# * Electronic Computer-Aided Design Integration
# * 3D Printed Circuit Board Geometry Import
# * Component Height Clearance Checking
# * Electrical Enclosure Thermal Relief Layout
# * Wire Harness Design
# * Cable Routing Paths
# * Electrical Connector Placement
# * Wiring Bundle Diameter Estimation
# * Cable Bend Radius Validation
# * Cable Clip Routing Channels
# * Busbar Routing in CAD Assemblies
# * High-Voltage Connector Spatial Layout
# * Slip Ring Integration Mechanics
#
# Manufacturing Preparation and Engineering Drawings:
#
# * Engineering Drawing Layouts
# * Orthographic Views
# * Isometric Views
# * Section Views
# * Detail Views
# * Geometric Dimensioning and Tolerancing
# * Datum Identifiers
# * Position Tolerances
# * Form Tolerances
# * Orientation Tolerances
# * Runout Tolerances
# * Bill of Materials Generation
# * STEP File Export Standards
# * STL Export Optimization for Additive Manufacturing
#
# Finite Element Analysis and Generative Design:
#
# * Finite Element Analysis Mesh Generation
# * Mesh Refinement Rules
# * Boundary Conditions Setup
# * Fixed Support Constraints
# * Load Vector Application
# * Thermal-Mechanical Stress Analysis
# * Stress Concentration Identification
# * Topology Optimization
# * Generative Design for Structural Castings
# * Design for Additive Manufacturing Optimization
#
# Spatial Geometry and Lie Theory:
#
# * Euclidean Space Transformations
# * Special Orthogonal Group SO(3)
# * Special Euclidean Group SE(3)
# * Lie Algebra so(3)
# * Lie Algebra se(3)
# * Exponential Map
# * Logarithm Map
# * Rotation Generators
# * Skew-Symmetric Matrices
# * Adjoint Transformations
# * Singularity-Free Coordinate Frames
#
# ## Robot Kinematics and Dynamics
#
# Kinematics and Jacobians:
#
# * Denavit-Hartenberg Parameters
# * Product of Exponentials Formulation
# * Forward Kinematic Chain Transformations
# * Inverse Kinematics Optimization
# * Levenberg-Marquardt Solvers
# * Analytic Jacobians
# * Spatial Jacobians
# * Manipulability Ellipsoids
# * Kinematic Singularity Identification
#
# Rigid Body and Humanoid Dynamics:
#
# * Newtonian Mechanics
# * Rigid Body Spatial Inertia
# * Inertia Tensors
# * Center of Mass Calculations
# * Lagrangian Mechanics
# * Equations of Motion
# * Recursive Newton-Euler Algorithm
# * Articulated Body Algorithm
# * Floating-Base Equations of Motion for Bipedal Systems
# * Centroidal Dynamics
# * Ground Reaction Force Mapping
#
# ## Control Theory and Whole-Body Control
#
# Classical Control:
#
# * Open-Loop Systems
# * Closed-Loop Systems
# * Transfer Functions
# * Block Diagram Reduction
# * Signal Flow Graphs
# * Transient Response Analysis
# * Steady-State Error Analysis
# * Frequency Domain Analysis
# * Bode Plots
# * Nyquist Stability Criterion
# * Nichols Charts
# * Root Locus Analysis
# * Phase Margins
# * Gain Margins
# * Proportional Integral Derivative Control
# * PID Controller Tuning Methods
# * Lead Compensation
# * Lag Compensation
#
# Modern State-Space Control Theory:
#
# * Continuous State-Space Representation
# * Discrete State-Space Representation
# * Controllability Matrix Analysis
# * Observability Matrix Analysis
# * Controllability Gramians
# * Observability Gramians
# * Full-State Feedback Control
# * Pole Placement Technique
# * Luenberger Observer Design
# * Separation Principle
# * Linear Quadratic Regulator
# * Linear Quadratic Gaussian Control
# * Algebraic Riccati Equations
# * Discrete Riccati Equations
#
# Optimal and Robust Control:
#
# * Dynamic Programming
# * Hamilton-Jacobi-Bellman Equation
# * Pontryagin Minimum Principle
# * Model Predictive Control over Finite Prediction Horizons
# * Explicit Model Predictive Control
# * Nonlinear Model Predictive Control
# * H-2 Optimal Control
# * H-Infinity Robust Control
# * Mu-Synthesis
# * Structured Singular Values
# * Sliding Mode Control
# * Chattering Suppression Techniques
#
# Nonlinear Control Theory:
#
# * Phase Plane Analysis
# * Limit Cycles
# * Lyapunov Direct Stability Method
# * Lyapunov Indirect Stability Method
# * Control Lyapunov Functions
# * Control Barrier Functions
# * Input-State Feedback Linearization
# * Input-Output Feedback Linearization
# * Zero Dynamics Analysis
# * Integrator Backstepping Control
# * Passivity-Based Control
# * Describing Functions Method
#
# Adaptive Control and System Identification:
#
# * Model Reference Adaptive Control
# * Self-Tuning Regulators
# * Auto-Regressive Exogenous System Identification
# * Output Error Model Identification
# * Frequency Domain System Identification
# * Iterative Learning Control
#
# Humanoid Whole-Body Control and Dynamic Balance:
#
# * Operational Space Control
# * Hierarchical Quadratic Programming
# * Whole-Body Control Frameworks
# * Impedance Control
# * Admittance Force Control
# * Hybrid Force-Position Control
# * Variable Impedance Control
# * Zero Moment Point Stability
# * Center of Pressure Stability
# * Linear Inverted Pendulum Model
# * Divergent Component of Motion
# * Capture Point Dynamics
# * Centroidal Angular Momentum Regulation
# * Contact-Implicit Trajectory Optimization
# * Whole-Body Model Predictive Control
#
# ## Systems Programming in Rust and Real-Time Computer Science
#
# Rust:
#
# * Ownership
# * Borrowing
# * Lifetimes
# * Zero-Cost Abstractions
# * Deterministic Memory Layouts
# * Allocation-Free Real-Time Execution (no\_std)
# * Single Producer Single Consumer Lock-Free Ring Buffers
# * Multi Producer Multi Consumer Lock-Free Ring Buffers
# * Wait-Free Ring Buffers
# * Send Thread Safety Guarantees
# * Sync Thread Safety Guarantees
# * High-Performance Custom Bitfield Parsing
#
# Real-Time Operating Systems and Industrial Communications:
#
# * RTOS Preemptive Priority-Based Scheduling
# * Cyclic Executive Execution Loops
# * CANopen Protocol State Machines
# * EtherCAT Process Data Object Deterministic Loops
# * Fault-Tolerant Finite State Machines for Operational Modes
#
# ## Estimation and State Fusion
#
# State Estimation Algorithms:
#
# * Bayesian Probability
# * Multivariate Gaussian Distributions
# * Linear Kalman Filter Derivation
# * Optimal Kalman Gain
# * Non-Linear System Linearization via Jacobians
# * Extended Kalman Filter Design
# * Unscented Kalman Filter Design
# * Sigma-Point Transformations
# * Multi-Sensor Base State Estimation
#
# ## FSD
#
# Perception Physics and Sensor Modeling:
#
# * Time-of-Flight LiDAR Ranging Physics
# * FMCW RADAR Doppler Shift Derivations
# * Capacitive MEMS Accelerometers
# * Gyroscopes
# * CMOS Image Sensors
# * Pinhole Camera Models
# * Camera Projection Matrices
# * Epipolar Geometry
# * Radial Lens Distortion Correction
# * Tangential Lens Distortion Correction
#
# Deep Learning Neural Architectures for FSD Perception:
#
# * Convolutional Backbone Feature Extraction
# * Transformer Attention Mechanisms for Spatial Perception
# * Bird's-Eye-View Perspective Spatial Transformations
# * 3D Bounding Box Bounding Volume Estimation
# * Multi-Task Perception Heads for Point Cloud Segmentation
# * Temporal Motion Prediction Neural Networks
# * Occupancy Grid Network Architecture
# * TensorRT Model Quantization and FPGA Acceleration
# * Neural State Estimation for Dynamic Moving Obstacles
#
# Spatial Mapping and Graph-SLAM:
#
# * Log-Odds Occupancy Grid Mapping
# * Graph-Based Simultaneous Localization and Mapping
# * Pose-Graph Optimization via Gauss-Newton Solvers
# * Pose-Graph Optimization via Levenberg-Marquardt Solvers
# * Loop Closure Constraint Insertion
# * Spatial Consistency Verification
#
# Graph Search and Motion Planning Algorithms:
#
# * Configuration Space Representation
# * Dijkstra's Search Algorithm
# * A\* Search Algorithm
# * Heuristic Admissibility Proofs
# * Hybrid A\* for Kinematically Constrained Non-Holonomic Vehicles
# * State-Lattice Planners
# * Motion Primitives
# * Rapidly-exploring Random Trees
# * RRT Star Optimization
# * Quintic Polynomial Trajectory Splines
# * Septic Polynomial Trajectory Splines
# * Minimum Jerk Trajectory Optimization
# * Minimum Snap Trajectory Optimization
#
# Path Tracking Control and Vehicle Dynamics:
#
# * Kinematic Bicycle Models
# * Dynamic Bicycle Models
# * Pure Pursuit Curvature Guidance
# * Stanley Cross-Track Error Stability Control
# * Linear Time-Varying Model Predictive Control for Lateral Guidance
# * Tire-Road Friction Dynamics
# * Dynamic Slip Angle Estimation
#
# Robotic FSD Systems Engineering:
#
# * Factory Floor Operational Design Domain Mapping
# * Prior Map Feature Alignment with Online Perception
# * Online Self-Correction under Ground Surface Perturbations
# * Dynamic Obstacle Velocity Field Tracking
# * Coordinated Footstep Placement and Navigation Trajectories
# * Automatic Recovery State Machines for Slippage and Blockages
# * Spatial Map Auto-Healing and Live Drift Correction
# * Real-Time Hardware Integration in Embedded Edge Accelerators
# * Deterministic Digital Twin Simulation Validation
# * Human-Robot Industrial Safe Distance Interlocks
#
# Safety Envelopes and Deterministic Architecture:
#
# * Operational Design Domain Boundaries
# * Responsibility-Sensitive Safety Mathematical Distance Models
# * Time-to-Collision Calculations
# * Multi-Channel Redundant Fail-Safe State Machines
# * ISO 26262 Functional Safety Integration (ASIL-D Standard)
